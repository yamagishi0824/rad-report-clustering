# %% [markdown]
# # import library

# %%
import pandas as pd
import numpy as np
np.random.seed(0)
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score, normalized_mutual_info_score, fowlkes_mallows_score

# %% [markdown]
# # load csv

# %%
# Load a CSV file containing extracted information
# Ensure the file includes a column named "text_json" that contains structured data in JSON format
df = pd.read_csv("../data/extracted_info.csv")

# %% [markdown]
# # functions to convert info to numeric values

# %%
import re

def extract_braced_content(s):
    match = re.search(r'\{(.*?)\}', s, re.DOTALL)
    return match.group(1).strip() if match else None

def remove_characters(s):
    return s.replace('\n', '').replace(':', '').replace(' ', '').replace(',', '').replace("、", "").replace("{", "").replace("}", "")


def convert_to_mm(value):
    # mmでの表記をチェック
    mm_match = re.search(r'(\d+(\.\d+)?)mm', value)
    if mm_match:
        return int(mm_match.group(1))

    # cmでの表記をチェック
    # cm_match = re.search(r'(\d+(\.\d+)?)cm', value)
    # if cm_match:
    #     return int((cm_match.group(1)) * 10)

    # 単位がない場合の数値をチェック
    num_match = re.search(r'(\d+(\.\d+)?)', value)
    if num_match:
        return int(num_match.group(1))
    
    if ("巨大" in value) | ("大き" in value):
        return "huge"

    # 一致しない場合は元のまま返す
    return value

# %% [markdown]
# # execute the conversion

# %%
errors = 0
texts = []
for text in df["text_json"]:
    if not("}" in text):
        text += "}"
    try:
        #print(text)
        if "{" in text:
            text =  extract_braced_content(text)
        #print(text)
        text = remove_characters(text)
        text = text.split('"')
        text = [text for text in text if text]
        #print(text)
        #break
    except:
        print(text)
        errors += 1
        print(errors)
    texts.append(text)

# %%
infos = []
num_data = []
for text in texts:
    # try:
    # print(text)
    if not("転移" in text):
        text += ['転移', 'なし']
    if text != None:
        id_size, id_loc, id_ly, id_meta = text.index("大きさ")+1, text.index("腫瘍の場所")+1, text.index("リンパ節腫大")+1, text.index("転移")+1
        size, location, ly, meta = text[id_size], text[id_loc], text[id_ly], text[id_meta]
        cm = "cm" in size and "." not in size
        size = size.replace(".", "")
        size = convert_to_mm(size)
        if cm & (size != "huge"):
            size *= 10
        if size == "huge":
            size == 71
        lat = -1
        lob = -1
        if "左" in location:
            lat += 0 #"左"
        if "右" in location:
            lat += 1 #"右"
        if "上" in location:
            lob += 0 #"上"
        if "中" in location:
            lob += 1 #"中"
        if "下" in location:
            lob += 2 #"下"
        # if new_loc == "":
        #     lob = location
        size_num = size
        if type(size_num) != int:
            size_num = -1
        # print(size_num)
        # print(size, location, ly, meta)
        dic_info = {"size": size,
                    "size_num": size_num,
                    "location": location,
                    "lob": lob,
                    "lat": lat,
                    "ly": ly,
                    "meta": meta}
        infos.append(dic_info)
        num_ = np.array([size_num, lob, lat])
        num_data.append(num_)
        # print(dic_info)
    else:
        dic_info = {"size": -1,
                    "size_num": -1,
                    "location": -1,
                    "lob": -1,
                    "lat": -1,
                    "ly": -1,
                    "meta": -1}
        infos.append(dic_info)
        num_ = np.array([size_num, lob, lat])
        num_data.append(num_)
        #print(text)
    # except:
    #     print(text)

# %%
df["extracted"] = infos
infos
# Out:
# [{'size': 18,
#   'size_num': 18,
#   'location': '左上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 18,
#   'size_num': 18,
#   'location': '肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 18,
#   'size_num': 18,
#   'location': 'S1+2',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 18,
#   'size_num': 18,
#   'location': '左上葉S1+2',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 15,
#   'size_num': 15,
#   'location': '左肺上葉S1+2',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 18,
#   'size_num': 18,
#   'location': '左肺上葉の外側',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'null',
#   'meta': 'null'},
#  {'size': 10,
#   'size_num': 10,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 18,
#   'size_num': 18,
#   'location': '左肺上葉S1+2',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 18,
#   'size_num': 18,
#   'location': '左肺上葉S1+2',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'はない',
#   'meta': 'ない'},
#  {'size': 12,
#   'size_num': 12,
#   'location': '右下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 12,
#   'size_num': 12,
#   'location': '右肺下葉S6',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 12,
#   'size_num': 12,
#   'location': '左肺下葉S6',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 12,
#   'size_num': 12,
#   'location': '右下葉S6',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 12,
#   'size_num': 12,
#   'location': '左肺下葉S6',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 12,
#   'size_num': 12,
#   'location': '右肺下葉S6',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 12,
#   'size_num': 12,
#   'location': '肺下葉',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 12,
#   'size_num': 12,
#   'location': '右下葉S6',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 12,
#   'size_num': 12,
#   'location': '右肺下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 28,
#   'size_num': 28,
#   'location': '左舌区',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 28,
#   'size_num': 28,
#   'location': '左肺舌区',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 28,
#   'size_num': 28,
#   'location': '左肺上区S3',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 28,
#   'size_num': 28,
#   'location': '右上葉S3',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 28,
#   'size_num': 28,
#   'location': '左肺上葉S4',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 28,
#   'size_num': 28,
#   'location': '左肺舌区S4の外側',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 28,
#   'size_num': 28,
#   'location': '左舌区に気管支区域に沿った',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 28,
#   'size_num': 28,
#   'location': '左舌区S4',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 24,
#   'size_num': 24,
#   'location': '左肺⾆区S4',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'ない'},
#  {'size': 40,
#   'size_num': 40,
#   'location': '左上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 40,
#   'size_num': 40,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'NX'},
#  {'size': 40,
#   'size_num': 40,
#   'location': '左肺上区',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 40,
#   'size_num': 40,
#   'location': '左上葉S1+2',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 40,
#   'size_num': 40,
#   'location': '左肺上葉S1+2',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 40,
#   'size_num': 40,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 40,
#   'size_num': 40,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 40,
#   'size_num': 40,
#   'location': '左上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 40,
#   'size_num': 40,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 48,
#   'size_num': 48,
#   'location': '左上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'なし'},
#  {'size': 48,
#   'size_num': 48,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 48,
#   'size_num': 48,
#   'location': '葉間裂',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': '疑い'},
#  {'size': 48,
#   'size_num': 48,
#   'location': '左上葉S1+2',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'あり'},
#  {'size': 48,
#   'size_num': 48,
#   'location': 'S1+2',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 48,
#   'size_num': 48,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 48,
#   'size_num': 48,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 48,
#   'size_num': 48,
#   'location': '左舌区S4',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 48,
#   'size_num': 48,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'ない'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '右肺門部',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 'null',
#   'size_num': -1,
#   'location': 'null',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': '未測定',
#   'size_num': -1,
#   'location': '右肺',
#   'lob': -1,
#   'lat': 0,
#   'ly': '右下葉右上葉左上葉',
#   'meta': 'なし'},
#  {'size': 'null',
#   'size_num': -1,
#   'location': 'null',
#   'lob': -1,
#   'lat': -1,
#   'ly': '1L',
#   'meta': 'なし'},
#  {'size': 2,
#   'size_num': 2,
#   'location': '右肺下葉肺門部',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'N3',
#   'meta': 'N3'},
#  {'size': 120,
#   'size_num': 120,
#   'location': '右下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '右肺中葉下葉',
#   'lob': 2,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': '?',
#   'size_num': -1,
#   'location': '?',
#   'lob': -1,
#   'lat': -1,
#   'ly': '?',
#   'meta': 'N3'},
#  {'size': 15,
#   'size_num': 15,
#   'location': '右肺下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': '22mm',
#   'meta': 'なし'},
#  {'size': 55,
#   'size_num': 55,
#   'location': '右下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'true',
#   'meta': 'true'},
#  {'size': 55,
#   'size_num': 55,
#   'location': '右肺下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'N2'},
#  {'size': 55,
#   'size_num': 55,
#   'location': '右肺下葉肺門側',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 55,
#   'size_num': 55,
#   'location': '右下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 55,
#   'size_num': 55,
#   'location': '右肺下葉気管支',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 55,
#   'size_num': 55,
#   'location': '右肺下葉の中枢側',
#   'lob': 2,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'ない'},
#  {'size': 55,
#   'size_num': 55,
#   'location': '右肺下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 55,
#   'size_num': 55,
#   'location': '右肺門部',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'N2'},
#  {'size': 55,
#   'size_num': 55,
#   'location': '右肺下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'true',
#   'meta': '肝'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '左上葉背側',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 'null',
#   'size_num': -1,
#   'location': '左肺尖部背側',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': '○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大',
#   'size_num': -1,
#   'location': '肺',
#   'lob': -1,
#   'lat': -1,
#   'ly': '転移',
#   'meta': '転移'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '左肺尖部',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 'huge',
#   'size_num': -1,
#   'location': '左肺尖部',
#   'lob': -1,
#   'lat': -1,
#   'ly': '左鎖骨上窩リンパ節も腫脹しておりリンパ節転移があるようです。',
#   'meta': 'ない'},
#  {'size': 25,
#   'size_num': 25,
#   'location': '左肺上葉肺尖部付近',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 'huge',
#   'size_num': -1,
#   'location': '左肺尖部',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'ない'},
#  {'size': 30,
#   'size_num': 30,
#   'location': '左肺尖部',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 50,
#   'size_num': 50,
#   'location': '左肺尖部',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 43,
#   'size_num': 43,
#   'location': '右肺門部',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 43,
#   'size_num': 43,
#   'location': '右肺門',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 43,
#   'size_num': 43,
#   'location': '右肺門',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 43,
#   'size_num': 43,
#   'location': '右下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': '右側乳房胸壁皮下肝右副腎骨盤腔右側に多発結節'},
#  {'size': 43,
#   'size_num': 43,
#   'location': '右肺下葉辺縁',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'N3'},
#  {'size': 43,
#   'size_num': 43,
#   'location': '右肺下葉から肺門部',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 25,
#   'size_num': 25,
#   'location': '右肺下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': '右肺上葉右肺門同側縦隔対側縦隔対側肺門左鎖骨上窩',
#   'meta': '皮膚肝右副腎'},
#  {'size': 43,
#   'size_num': 43,
#   'location': '右肺下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 43,
#   'size_num': 43,
#   'location': '右肺下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'true',
#   'meta': '肺'},
#  {'size': 'null',
#   'size_num': -1,
#   'location': '右上葉',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'null',
#   'meta': 'null'},
#  {'size': 'null',
#   'size_num': -1,
#   'location': '右肺上葉中枢側',
#   'lob': 0,
#   'lat': 0,
#   'ly': 'null',
#   'meta': 'null'},
#  {'size': '○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大',
#   'size_num': -1,
#   'location': '右肺上葉',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 'なし',
#   'size_num': -1,
#   'location': '上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '右肺上葉肺門部',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 25,
#   'size_num': 25,
#   'location': '右肺上葉',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 'huge',
#   'size_num': -1,
#   'location': '右肺上葉',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 50,
#   'size_num': 50,
#   'location': '右上葉',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'なし'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '右上葉',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'なし'},
#  {'size': 'huge',
#   'size_num': -1,
#   'location': '右肺',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'あり'},
#  {'size': 'huge',
#   'size_num': -1,
#   'location': '右肺',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': '○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大○×○cm大',
#   'size_num': -1,
#   'location': '右肺',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 'なし',
#   'size_num': -1,
#   'location': '右肺尖部',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 'huge',
#   'size_num': -1,
#   'location': '右肺尖部',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 25,
#   'size_num': 25,
#   'location': '肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 'huge',
#   'size_num': -1,
#   'location': '右肺尖部',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': '右肺下葉に多発結節'},
#  {'size': 25,
#   'size_num': 25,
#   'location': '右肺尖部',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 25,
#   'size_num': 25,
#   'location': '右肺',
#   'lob': -1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': '不明',
#   'size_num': -1,
#   'location': '右下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'あり'},
#  {'size': 'null',
#   'size_num': -1,
#   'location': 'null',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'null',
#   'meta': 'T因子'},
#  {'size': '○×○cm○×○cm○×○cm○×○cm○×○cm○×○cm○×○cm○×○cm○×○cm○×○cm',
#   'size_num': -1,
#   'location': '右肺下葉',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'cM1c'},
#  {'size': 'null',
#   'size_num': -1,
#   'location': '右下葉S6',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'null',
#   'meta': 'null'},
#  {'size': 'なし',
#   'size_num': -1,
#   'location': '右肺下葉S10',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': '約Xcm約Xcm約Xcm約Xcm約Xcm約Xcm約Xcm約Xcm約Xcm約Xcm',
#   'size_num': -1,
#   'location': '右肺下葉の内側',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': '両側肺野右肺門縦隔第8～11胸椎'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '右肺下葉S6',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 'なし',
#   'size_num': -1,
#   'location': '右下葉縦隔側',
#   'lob': 1,
#   'lat': 0,
#   'ly': 'なし',
#   'meta': 'M1c'},
#  {'size': 35,
#   'size_num': 35,
#   'location': '両肺',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'あり'},
#  {'size': 78,
#   'size_num': 78,
#   'location': '左下葉末梢',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 78,
#   'size_num': 78,
#   'location': '胸膜下',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 78,
#   'size_num': 78,
#   'location': '左肺下葉',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 78,
#   'size_num': 78,
#   'location': '右下葉S9',
#   'lob': 1,
#   'lat': 0,
#   'ly': '#5#7縦隔リンパ節',
#   'meta': 'N2相当'},
#  {'size': 78,
#   'size_num': 78,
#   'location': '左肺下葉S9',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 78,
#   'size_num': 78,
#   'location': '左肺下葉',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': '肺門縦隔リンパ節左肺転移を疑う様な病変は指摘できません。'},
#  {'size': 'huge',
#   'size_num': -1,
#   'location': '左肺下葉',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 78,
#   'size_num': 78,
#   'location': '左下葉S9',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 78,
#   'size_num': 78,
#   'location': '左肺下葉',
#   'lob': 1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 25,
#   'size_num': 25,
#   'location': '左肺静脈',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 30,
#   'size_num': 30,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 85,
#   'size_num': 85,
#   'location': '左肺門',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 50,
#   'size_num': 50,
#   'location': '左上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 85,
#   'size_num': 85,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 120,
#   'size_num': 120,
#   'location': '肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '左上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 'null',
#   'size_num': -1,
#   'location': 'null',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'null',
#   'meta': 'null'},
#  {'size': '?',
#   'size_num': -1,
#   'location': '?',
#   'lob': -1,
#   'lat': -1,
#   'ly': '?',
#   'meta': '?'},
#  {'size': 4,
#   'size_num': 4,
#   'location': '左肺門',
#   'lob': -1,
#   'lat': -1,
#   'ly': '左肺門リンパ節と一塊',
#   'meta': '転移を疑います(cN2)。またTh6・7傍椎体には腫瘤を認めまた左第6肋骨には新たな膨隆性の骨硬化像が出現しています。他にも肝内に新たな低吸収域右副腎結節の出現あり短期間での経過の病勢の増悪(転移)が示唆されます(M1c)。右肺中葉や左肺舌区には陳旧性炎症性変化を疑う線状索状影を認めます。左胸水を認めます。甲状腺右葉の腫瘤や左葉の低吸収結節は以前のCTと著変ありません。Impression(記載箇所あれば)：左肺門部肺癌−左上葉無気肺(c'},
#  {'size': 4,
#   'size_num': 4,
#   'location': '左上葉気管支は閉塞しており左上葉気管支近位部周囲には肺癌を疑う腫瘤が認められます。左上肺静脈末梢側に浸潤しています。',
#   'lob': -1,
#   'lat': -1,
#   'ly': '左肺門部リンパ節腫大と一塊となっているようです。右下葉には2個のいずれも⻑径7mmの結節を認めます。',
#   'meta': '左肺門部リンパ節#5#6リンパ節が腫大しておりリンパ節転移を疑います。N分類でN2相当と思われます。左胸水貯留が出現しています。'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '肺門部',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': 'なし'},
#  {'size': 20,
#   'size_num': 20,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'なし',
#   'meta': '右肺転移左第6肋骨転移を疑います'},
#  {'size': 300,
#   'size_num': 300,
#   'location': '縦隔',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 25,
#   'size_num': 25,
#   'location': '左上葉肺門部',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'},
#  {'size': 100,
#   'size_num': 100,
#   'location': '左肺上葉',
#   'lob': -1,
#   'lat': -1,
#   'ly': 'あり',
#   'meta': 'あり'}]

# %% [markdown]
# # execute clustering & performance evaluation

# %%
# train test split, according to NTCIR-16
train_idx = (~df["case"].isin([4, 5, 7, 8, 10, 14, 15])).values
test_idx = (df["case"].isin([4, 5, 7, 8, 10, 14, 15])).values
train_labels = df["case"][train_idx].values
test_labels = df["case"][test_idx].values
num_data = np.array(num_data)

# %%
# train
targets = train_labels
train_data = num_data[train_idx]

# clustering
kmeans = KMeans(n_clusters=8, init='k-means++', random_state=0, n_init=30, max_iter=300).fit(train_data)
labels = kmeans.labels_

# evaluation
nmi = normalized_mutual_info_score(targets, labels)
ami = adjusted_mutual_info_score(targets, labels)
fm = fowlkes_mallows_score(targets, labels)

print("NMI:", nmi)
print("AMI:", ami)
print("FM:", fm)
# Out:
# NMI: 0.7152308022894814
# AMI: 0.651563954939907
# FM: 0.5958636987797016

# %%
# test
targets = test_labels
train_data = num_data[test_idx]

# clustering
kmeans = KMeans(n_clusters=8, init='k-means++', random_state=0, n_init=30, max_iter=300).fit(train_data)
labels = kmeans.labels_

# evaluation
nmi = normalized_mutual_info_score(targets, labels)
ami = adjusted_mutual_info_score(targets, labels)
fm = fowlkes_mallows_score(targets, labels)

print("NMI:", nmi)
print("AMI:", ami)
print("FM:", fm)
# Out:
# NMI: 0.6413658311220682
# AMI: 0.5597516941130994
# FM: 0.5354496700964052

# %% [markdown]
# # robustness test

# %%
def robust_test(targets, noisy_data):
    noise_scale = 0.05 * np.abs(noisy_data)
    noise = (2 * np.random.rand(noisy_data.shape[0], noisy_data.shape[1]) - 1 ) * noise_scale
    noisy_data = noisy_data + noise

    kmeans = KMeans(n_clusters=8, init='k-means++', random_state=0, n_init=30, max_iter=300).fit(noisy_data)
    labels = kmeans.labels_

    nmi = normalized_mutual_info_score(targets, labels)
    ami = adjusted_mutual_info_score(targets, labels)
    fm = fowlkes_mallows_score(targets, labels)
    return nmi, ami, fm

def repeat_test(targets, noisy_data, n=1000):
    nmis, amis, fms = [], [], []
    for _ in range(n):
        nmi, ami, fm = robust_test(targets, noisy_data)
        nmis.append(nmi) ; amis.append(ami) ; fms.append(fm)
    return nmis, amis, fms

train_result = repeat_test(targets=train_labels, noisy_data=num_data[train_idx], n=1000)
test_result = repeat_test(targets, noisy_data=num_data[test_idx], n=1000)

# %%
def calc_95ci(data):
    lower = np.percentile(data, 2.5)
    upper = np.percentile(data, 97.5)
    return (lower, upper)

def calc_each_95ci(result):
    nmi, ami, fm = result[0], result[1], result[2]
    nmi_ci = calc_95ci(nmi)
    ami_ci = calc_95ci(ami)
    fm_ci = calc_95ci(fm)
    return nmi_ci, ami_ci, fm_ci

# show the result
train_metrics = calc_each_95ci(train_result)
test_metrics = calc_each_95ci(test_result)
print("train (nmi, ami, fm):", train_metrics)
print("test (nmi, ami, fm):", test_metrics)
# Out:
# train (nmi, ami, fm): ((0.6758776550012524, 0.7309308755769508), (0.6006926495237799, 0.6676091287745058), (0.5412658773652742, 0.6014065304058602))
# test (nmi, ami, fm): ((0.5310163601046471, 0.645449546876431), (0.4244588336018941, 0.5634156761737154), (0.4477095516335758, 0.5379459524869229))
